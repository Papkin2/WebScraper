# %%
pip install requests

# %%
pip install BeautifulSoup4

# %% [markdown]
# ## Import bibliotek

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# potencjalne produkty:
# *   124893467
# *   Element listy

# %% [markdown]
# ## Pobrane z serwisu [Ceneo.pl](https://Ceneo.pl) opinii o wybranym produkcie
# Wysłanie żądania dostępu do zasobu (strony WWW)

# %%
headers = {
    'Cookie' : 'sv3=1.0_a8e5d049-1e00-11f1-9fca-d7539bce9c3a; urdsc=2; userCeneo=ID=de317dd4-2aab-4b15-acac-0dcd4b2bfddf; __RequestVerificationToken=jur9yGhzZmzrlhB0NKu6qX6QICst326zMIplf9A2p7zEiA6SacviBSYXtsNZF0mMkx-uNo2PoU_r9nysiWwXOzpyauZmlu7njYfUQVE5bnw1; st2=_gd%3dwww.google.com%2csref%3dhttps%3a%2f%2fwww.google.com%2f%2c_t%3d63908912760%2cencode%3dtrue; ai_user=TSybp|2026-03-12T10:46:01.626Z; __utmf=0951e77eacc681f9c32401b00333ffe2_Dsgqi6QMc9CtX7buqOpcIw%3D%3D; appType=%7B%22Value%22%3A1%7D; cProdCompare_v2=; __rtbh.u…lhSZjkxbkNXS0pvJTJGajhLdU1GcFJWRHFwbm1wb0tPeDU4NCUyRkdWQkxoSEpPeUdVMXdJeFdxREdscmNyZG0zaDVEa1JCMmt3d3ZKUlY5b2xxMGE4UWJ4R3hlVkFEOUVtdnY5T2hwWVMlMkZta3NSNDZhWW9GcmlOSSUzRA; __gads=ID=4ec437f96da97d8d:T=1773314196:RT=1773314560:S=ALNI_MZqfXvHLkamXdz7ptqrLcqpdcP4MA; __gpi=UID=0000134cc46a9302:T=1773314196:RT=1773314560:S=ALNI_MYMTOKAYxXqo76XNUOXgvbH6ION0g; __eoi=ID=7f8bd1c4a41d0a0f:T=1773314196:RT=1773314560:S=AA-AfjYFykSTaIcpiA-PnIEHZPv7; widgetsDisabled=[{"id":120034,"dateTo":"2026-04-11T11:26:09.8365722Z"}]',
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:148.0) Gecko/20100101 Firefox/148.0',
    'Host' : 'www.ceneo.pl'
}

# %%
url = 'https://www.ceneo.pl/124893467#tab=reviews'
requests.get(url)
response = requests.get(url, headers=headers)
print(response.status_code)
page_dom = BeautifulSoup(response.text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# /tmp/ipykernel_442/1071315716.py in <cell line: 0>()
#       1 url = 'https://www.ceneo.pl/124893467#tab=reviews'
#       2 requests.get(url)
# ----> 3 response = requests.get(url, headers=headers)
#       4 print(response.status_code)
#       5 page_dom = BeautifulSoup(response.text, 'html.parser')
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %%
opinion = page_dom.find_all('div', class_ = 'js_product-review')
print(opinion)
#
# Out:
# []
